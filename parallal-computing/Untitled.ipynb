# %%
import numpy as np
import pandas as pd

from sklearn.datasets import load_iris
from sklearn.model_selection import (
    train_test_split,
    KFold,
    LeaveOneOut,
    LeavePOut,
    cross_val_score
)
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
iris = load_iris()
X = iris.data      # features
y = iris.target    # labels

# %%
model = LogisticRegression(max_iter=200)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Hold-Out Accuracy:", accuracy)
# Out:
# Hold-Out Accuracy: 1.0

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

scores = cross_val_score(model, X, y, cv=kfold)

print("K-Fold Accuracies:", scores)
print("Average Accuracy:", scores.mean())
# Out:
# K-Fold Accuracies: [1.         1.         0.93333333 0.96666667 0.96666667]
# Average Accuracy: 0.9733333333333334

# %%
loo = LeaveOneOut()

scores = cross_val_score(model, X, y, cv=loo)

print("LOO Average Accuracy:", scores.mean())
# Out:
# LOO Average Accuracy: 0.9666666666666667

# %%
lpo = LeavePOut(p=2)

scores = cross_val_score(model, X, y, cv=lpo)

print("Leave-P-Out Average Accuracy:", scores.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 lpo = LeavePOut(p=2)
# ----> 3 scores = cross_val_score(model, X, y, cv=lpo)
#       5 print("Leave-P-Out Average Accuracy:", scores.mean())
#
# NameError: name 'model' is not defined
